# %%
import csv
def import_text(filename, separator):
    reader= csv.DictReader(open(filename), delimiter=separator, skipinitialspace=True)
    for line in reader:
        if line:
            yield line


current=[]
voltage=[]
for data in import_text('./Data/nmos_test.txt', '\t'):
        current.append(data['Id(M1)']) 
        voltage.append(data['V1'])

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(voltage,current)
plt.xlabel('voltage')
plt.ylabel('current')
plt.title('From LTSPICE')
plt.show()

# %%
import numpy
numpy.size(voltage)
# Out:
# 181

# %%
currentTh=[]
currentSql=[]
Vth=0.477
for i in range(181):
    if(float(voltage[i])<0.57-Vth):
        c=171e-6*2*(2)*(float(voltage[i]))*((0.57-Vth)-(0.5*float(voltage[i])))
        currentTh.append(c)
        
    elif(float(voltage[i])>0.57-Vth):
        c=171e-6*(2)*(0.57-Vth)**2
        currentTh.append(c)

# %%
plt.figure(0)
from matplotlib.pyplot import *
PWL=plt.plot(voltage,current)
#NL=plt.plot(timeNL,solnNL[:,9])
L1=plt.plot(voltage,currentTh)
#L2=plt.plot(voltage,currentSql)
#NLActual=plt.plot(timeNL,solnNLActual[:,9])
plt.title('Comparision b/w solutions')
#plt.figlegend([PWL,L1,L2],('From PSPICE','Square Law approx','Actual Square'),'lower right')
plt.xlabel('Voltage')
plt.ylabel('Current')
plt.show()

# %%
print "At voltage=",voltage[150]," Actual Current is =", current[150]
# Out:
# At voltage= 1.500000000000001e+000  Actual Current is = 5.035724e-006

# %%
gds=(float(current[150])-float(currentTh[150]))/float(voltage[150])
print "gds =",gds
# Out:
# gds = 1.38517733333e-06

# %%
currentTh=[]
currentSql=[]
Vth=0.477

for i in range(181):
    if(float(voltage[i])<0.57-Vth):
        c=171e-6*2*(2)*(float(voltage[i]))*((0.57-Vth)-(0.5*float(voltage[i])))
        currentTh.append(c)
        currentSql.append(c)
    elif(float(voltage[i])>0.57-Vth):
        c=171e-6*(2)*(0.57-Vth)**2
        currentTh.append(c) 
        c=171e-6*(2)*(0.57-Vth)**2+(gds)*(float(voltage[i]))
        currentSql.append(c)

# %%
plt.figure(1)
PWL=plt.plot(voltage,current)
L1=plt.plot(voltage,currentTh)
L2=plt.plot(voltage,currentSql)

plt.title('Comparision b/w solutions')

plt.xlabel('Voltage')
plt.ylabel('Current')
plt.show()

# %%
currentTh=[]
currentSql=[]
Vth=0.44
for i in range(181):
    if(float(voltage[i])<0.57-Vth):
        c=171e-6*2*(2)*(float(voltage[i]))*((0.57-Vth)-(0.5*float(voltage[i])))
        currentTh.append(c)
        
    elif(float(voltage[i])>0.57-Vth):
        c=171e-6*(2)*(0.57-Vth)**2
        currentTh.append(c)

# %%
plt.figure(3)
PWL=plt.plot(voltage,current)
#NL=plt.plot(timeNL,solnNL[:,9])
L1=plt.plot(voltage,currentTh)
#L2=plt.plot(voltage,currentSql)
#NLActual=plt.plot(timeNL,solnNLActual[:,9])
plt.title('Comparision b/w solutions')
#plt.figlegend([PWL,L1,L2],('From PSPICE','Square Law approx','Actual Square'),'lower right')
plt.xlabel('Voltage')
plt.ylabel('Current')
plt.show()

# %%
(float(current[150])-float(currentTh[150]))/float(voltage[150])
# Out:
# -4.960506666666637e-07

# %%
currentTh=[]
currentSql=[]
Vth=0.44
for i in range(181):
    if(float(voltage[i])<0.57-Vth):
        c=171e-6*2*(2)*(float(voltage[i]))*((0.57-Vth)-(0.5*float(voltage[i])))
        currentTh.append(c)
        currentSql.append(c)
    elif(float(voltage[i])>0.57-Vth):
        c=171e-6*(2)*(0.57-Vth)**2
        currentTh.append(c) 
        c=171e-6*(2)*(0.57-Vth)**2+(-4.960506666666637e-07)*(float(voltage[i]))
        currentSql.append(c)

# %%
plt.figure(3)
PWL=plt.plot(voltage,current)
#NL=plt.plot(timeNL,solnNL[:,9])
L1=plt.plot(voltage,currentTh)
L2=plt.plot(voltage,currentSql)
#NLActual=plt.plot(timeNL,solnNLActual[:,9])
plt.title('Comparision b/w solutions')
#plt.figlegend([PWL,L1,L2],('From PSPICE','Square Law approx','Actual Square'),'lower right')
plt.xlabel('Voltage')
plt.ylabel('Current')
plt.show()

# %% [markdown]
# ##Reducing level of MOS equations used *level=1*
#
# The library used is provided [here](http://www.engr.uky.edu/~ee562/Model.html). Using this I ran LTSPICE on the circuit, to have the Id vs Vds curve. Which seems to fit well with the equations provided in [here](file:///home/bhargava/ddp/references/MOS_models_with_eqs.pdf)

# %%
import csv
def import_text(filename, separator):
    reader= csv.DictReader(open(filename), delimiter=separator, skipinitialspace=True)
    for line in reader:
        if line:
            yield line


current=[]
voltage=[]
for data in import_text('./Data/nmos_test_lev1.txt', '\t'):
        current.append(data['Id(M1)']) 
        voltage.append(data['v1'])
plt.plot(voltage,current)
plt.xlabel('voltage')
plt.ylabel('current')
plt.title('From LTSPICE')
plt.show()

# %%
currentTh=[]
currentSql=[]
Vth=0.77
Vgs=2.0
Kp=7.7e-5
lamb=0.0625
for i in range(len(voltage)):
    Vds=float(voltage[i])
    if(float(voltage[i])<Vgs-Vth):
        c=Kp*(2)*(1+lamb*Vds)*(Vgs-Vth-(0.5*Vds))*Vds
        currentTh.append(c)
        
    elif(float(voltage[i])>Vgs-Vth):
        c=(1+(0.0625*Vds))*Kp*0.5*2*(Vgs-Vth)**2
        currentTh.append(c) 
    
plt.plot(voltage,currentTh,voltage,current)


plt.show()

# %% [markdown]
# ### Comparing lev49 and lev1 for *NMOS* for the same dimensions

# %%
import csv
def import_text(filename, separator):
    reader= csv.DictReader(open(filename), delimiter=separator, skipinitialspace=True)
    for line in reader:
        if line:
            yield line


current=[]
voltage=[]
for data in import_text('./Data/nmos_test_lev1_act.txt', '\t'):
        current.append(data['Id(M1)']) 
        voltage.append(data['v1'])
plt.plot(voltage,current)
plt.xlabel('voltage')
plt.ylabel('current')
plt.title('From LTSPICE')
plt.show()

# %%
import csv
def import_text(filename, separator):
    reader= csv.DictReader(open(filename), delimiter=separator, skipinitialspace=True)
    for line in reader:
        if line:
            yield line


current1=[]
voltage1=[]
for data in import_text('./Data/nmos_test_lev49_act.txt', '\t'):
        current1.append(data['Id(M1)']) 
        voltage1.append(data['v1'])
plt.plot(voltage1,current1,voltage,current)
plt.xlabel('voltage')
plt.ylabel('current')
plt.title('From LTSPICE')
plt.show()

# %% [markdown]
# ### Comparing currents for 2u/.24u *PMOS* with both level1 and level49 models

# %%
import csv
def import_text(filename, separator):
    reader= csv.DictReader(open(filename), delimiter=separator, skipinitialspace=True)
    for line in reader:
        if line:
            yield line


current=[]
voltage=[]
for data in import_text('./Data/pmos_test_lev1_2_0.24.txt', '\t'):
        current.append(data['Is(M1)']) 
        voltage.append(data['v1'])
plt.plot(voltage,current)
plt.xlabel('voltage')
plt.ylabel('current')
plt.title('From LTSPICE')
plt.show()

# %%
import csv
def import_text(filename, separator):
    reader= csv.DictReader(open(filename), delimiter=separator, skipinitialspace=True)
    for line in reader:
        if line:
            yield line


current1=[]
voltage1=[]
for data in import_text('./Data/pmos_test_lev49_2_0.24.txt', '\t'):
        current1.append(data['Is(M1)']) 
        voltage1.append(data['v1'])
plt.plot(voltage1,current1,voltage,current)
plt.xlabel('voltage')
plt.ylabel('current')
plt.title('From LTSPICE')
plt.show()

# %%
def current(d,g,s,w,l,vth):
    #d=state[information[1]]
    #g=state[information[2]]
    #s=state[information[3]]
    #p=re.compile('(l|w|=|u)')
    #w=float(p.sub('',information[5]))
    #l=float(p.sub('',information[6]))
    #vth=float(vth)
    #cur=abs(float(cur))
    #sub1={state[i]:datapoints[point][i] for i in state}
    
    
        if(s-g<=vth):
            return 0
        elif(s-d>s-g-vth):
            cc=(43e-6)*(w/l)*((g**2)+(1-2*vth*0.14)*(s**2)+(vth**2)+((0.14*vth-1)*2*g*s)+(2*g*vth)+(-2*vth+0.14*vth**2)*s-(0.14*d*vth**2)-(0.14*d*g**2)-(0.14*d*s**2)+(2*g*s*0.14*d)-(2*g*vth*0.14*d)+(2*s*vth*0.14*d)+(0.14*s*g**2)+(0.14*s**3)-(0.14*2*g*s**2))
            #cc=(43e-6)*(w/l)*(1+0.14*(s-d))*(s**2+g**2+vth**2-2*g*s-2*s*vth+2*g*vth)
            return cc
        elif(s-d<s-g-vth):
            cc=(86e-6)*(w/l)*((0.5*s**2)-(0.5*d**2)+(d*vth)-(s*vth)-(s*g)+(g*d))
            #cc=(86e-6)*(w/l)*(s-g-vth-(s-d)*0.5)*(s-d)
            return  cc

# %%
curcheck=[]
for i in voltage:
    curcheck.append(current(0,float(i)-0.7,float(i),64,0.24,0.477))
plt.plot(voltage,curcheck)
plt.show()

# %% [markdown]
# ##Checking for correctness of current equations after including $\lambda$ term for linear equations

# %%
import csv
def import_text(filename, separator):
    reader= csv.DictReader(open(filename), delimiter=separator, skipinitialspace=True)
    for line in reader:
        if line:
            yield line
current=[]
voltage=[]
for data in import_text('./Data/nmos_test_lev1_3_0.3_3.8.txt', '\t'):
        current.append(data['Id(M1)']) 
        voltage.append(data['v1'])
plt.plot(voltage,current)
plt.xlabel('voltage')
plt.ylabel('current')
plt.title('From LTSPICE')
plt.grid()
plt.figsize(10,10)
plt.show()

# %%
currentTh=[]
vth=0.477
w = 3
l = 0.3
g = 3.8
s = 0.0

for i in range(len(voltage)):
    d = float(voltage[i])
    if(float(voltage[i])<g - Vth) :
        c=(285e-6) * (w / l) * ((g * d) - (s * g) + (0.5 * s**2) - (vth * d) + (vth * s) - (0.5 * d**2) + (0.14 * g * d**2) - (2 * 0.14 * d * s * g) + (0.5 * 0.14 * d * s**2) - (0.14 * vth * d**2) + (2 * 0.14 * d * vth * s) - (0.5 * 0.14 * d**3) + (s**2 *g * 0.14) - (0.5 * 0.14 * s**3) - (0.14 * s**2 * vth) + (0.5 * 0.14 * s * d**2))
        currentTh.append(c)
        
    elif(float(voltage[i])>g - Vth) :
        c = (0.5 * 285e-6) * (w / l) * ((g**2) + (1-2 * vth * 0.14) * (s**2) + (vth**2) + ((0.14 * vth - 1) * 2 * g * s) - (2 * g * vth) + (2 * vth - 0.14 * vth**2) * s + (0.14 * d * vth**2) + (0.14 * d * g**2) + (0.14 * d * s**2) - (2 * g * s * 0.14 * d) - (2 * g * vth * 0.14 * d) + (2 * s * vth * 0.14 * d) - (0.14 * s * g**2) - (0.14 * s**3) + (0.14 * 2 * g * s**2))
        currentTh.append(c) 

calc, = plt.plot(voltage,currentTh,'--')
act, = plt.plot(voltage,current)
plt.legend((calc,act),('Calculated','LTSPICe'),'lower right')
plt.show()

# %% [markdown]
# Checking for PMOS with $\lambda$ added into the equations

# %%
import csv
def import_text(filename, separator):
    reader= csv.DictReader(open(filename), delimiter=separator, skipinitialspace=True)
    for line in reader:
        if line:
            yield line
current=[]
voltage=[]
for data in import_text('./Data/pmos_test_lev1_3_0.3_3.8.txt', '\t'):
        current.append(data['-Id(M1)']) 
        voltage.append(data['v1'])
plt.plot(voltage,current)
plt.xlabel('voltage')
plt.ylabel('current')
plt.title('From LTSPICE')
plt.show()

# %%
def current(information,vth):
    """Current equations verified for level 1 PMOS and NMOS
	The equations in this library have been incorporated after comparing results with LTSPICE models
	Any change in these equations has to be verified thoroughly with appropriate LTSPICE simulations.
	
	Returns:
	Symbolic equations with polynomial expansion """
    d=information[1]
    g=information[2]
    s=information[3]
    
    w=float(information[5])
    l=float(information[6])
    vth=float(vth)


    
    if(information[4]=='CMOSP'):
        if(information[0]=='c'):
            return 0
        elif(information[0]=='s'):
            cc=(43e-6) * (w / l) * ((g**2) + (1 - 2 * vth * 0.09) * (s**2) + (vth**2) + ((0.09 * vth - 1) * 2 * g * s) + (2 * g * vth) + (-2 * vth + 0.09 * vth**2) * s - (0.09 * d * vth**2) - (0.09 * d * g**2) -  (0.09 * d * s**2) + ( 2 * g * s * 0.09 * d) - (2 * g * vth * 0.09 * d) + ( 2* s * vth * 0.09 * d ) + (0.09 * s * g**2) + (0.09 * s**3) - (0.09 * 2 * g * s**2))
            return cc
        elif(information[0]=='l'):
            cc=(86e-6) * (w / l) * ((0.5 * s**2) - (0.5 * d**2) - (g * s) - (s * vth) + (g * d) + (d * vth) + (0.09 * 0.5 * s**3) - (0.09 * s * 0.5 * d**2) - (0.09 * g * s**2) - (s**2 * 0.09 * vth) + (2 * 0.09 * s * g * d) + (2 * 0.09 * s * d * vth) - (0.5 * d * 0.09 * s**2) + (0.5 * 0.09 * d**3) - (0.09 * g * d**2) - (0.09 * d**2 *vth))
            return  cc
        
    if(information[4]=='CMOSN'):
        if(information[0]=='c'):
            return 0
        elif(information[0]=='s'):
            cc = (0.5 * 285e-6) * (w / l) * ((g**2) + (1-2 * vth * 0.14) * (s**2) + (vth**2) + ((0.14 * vth - 1) * 2 * g * s) - (2 * g * vth) + (2 * vth - 0.14 * vth**2) * s + (0.14 * d * vth**2) + (0.14 * d * g**2) + (0.14 * d * s**2) - (2 * g * s * 0.14 * d) - (2 * g * vth * 0.14 * d) + (2 * s * vth * 0.14 * d) - (0.14 * s * g**2) - (0.14 * s**3) + (0.14 * 2 * g * s**2))
            return cc
        elif(information[0]=='l'):
            cc=(285e-6) * (w / l) * ((g * d) - (s * g) + (0.5 * s**2) - (vth * d) + (vth * s) - (0.5 * d**2) + (0.14 * g * d**2) - (2 * 0.14 * d * s * g) + (0.5 * 0.14 * d * s**2) - (0.14 * vth * d**2) + (2 * 0.14 * d * vth * s) - (0.5 * 0.14 * d**3) + (s**2 *g * 0.14) - (0.5 * 0.14 * s**3) - (0.14 * s**2 * vth) + (0.5 * 0.14 * s * d**2))
            return cc

import csv
def import_text(filename, separator):
    reader= csv.DictReader(open(filename), delimiter=separator, skipinitialspace=True)
    for line in reader:
        if line:
            yield line

# %%
w = 0.72e-6
l = 0.36e-6
file_current = './Data/NMOS_current.txt'
Vg = 1
Vs = 0
MOS = 'CMOSN'
drain = 'v1'

# %%
def Vds(start, final, incr):
    return numpy.linspace( start, final, (final - start)/incr )

# %%
from currenteqs import region
import matplotlib.pyplot as plt

# %%
Ids = [ current( [region(MOS,ds, Vg, Vs) , ds , Vg , Vs , MOS , w , l ] , 0.477)  for ds in Vds( 0, 1.8,0.01)]
calc, = plt.plot( Vds ( 0,1.8,0.01 ) , Ids)

cur=[]
voltage=[]
for data in import_text('./Data/NMOS_current.txt', '\t'):
        cur.append(data['Id(M1)']) 
        voltage.append(data[drain])
spice, = plt.plot(voltage,cur)
plt.xlabel('voltage')
plt.ylabel('current')
plt.title('From LTSPICE')
plt.figlegend((calc,spice),('Calc','Spice'),'lower right')
plt.figsize( 10,10)
plt.show()
